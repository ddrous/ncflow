# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = 'false'

from nodax import *
# jax.config.update("jax_debug_nans", True)




#%%


seed = 2026
# seed = int(np.random.randint(0, 10000))

context_pool_size = 1               ## Number of neighboring contexts j to use for a flow in env e
context_size = 256//1
nb_epochs = 10000
nb_epochs_adapt = 1500
init_lr = 1e-3
lr_factor = 0.1

print_error_every = 10

train = False
run_folder = "./runs/03082024-024220-Toy/"      ## Run folder to use when not training
reuse_run_folder = True

save_trainer = True

finetune = False

nb_outer_steps_max = 1000
nb_inner_steps_max = 20
proximal_beta = 1e1
inner_tol_node = 1e-16
inner_tol_ctx = 1e-16
early_stopping_patience = nb_outer_steps_max//1

adapt = True
adapt_huge = False

integrator = diffrax.Dopri5
# integrator = RK4
ivp_args = {"dt_init":1e-4, "rtol":1e-3, "atol":1e-6, "max_steps":4000, "subdivisions":10}
## subdivision is used for non-adaptive integrators like RK4. It's the number of extra steps to take between each evaluation time point
# Out:
# ############# Neural Context Flow #############
#
# Jax version: 0.4.28
# Available devices: [cuda(id=0)]

# %%
#%%

if train == True:

    # check that 'tmp' folder exists. If not, create it
    if not os.path.exists('./runs'):
        os.mkdir('./runs')

    # Make a new folder inside 'tmp' whose name is the current time
    if reuse_run_folder == False:
        run_folder = './runs/'+time.strftime("%d%m%Y-%H%M%S")+'/'
        os.mkdir(run_folder)
    # run_folder = "./runs/23012024-163033/"
    print("Run folder created successfuly:", run_folder)

    # Save the run and dataset scripts in that folder
    script_name = os.path.basename(__file__)
    os.system(f"cp {script_name} {run_folder}")
    os.system(f"cp dataset.py {run_folder}")

    # Save the nodax module files as well
    os.system(f"cp -r ../../nodax {run_folder}")
    print("Completed copied scripts ")


else:
    # run_folder = "./runs/22022024-112457/"  ## Needed for loading the model and finetuning TODO: opti
    print("No training. Loading data and results from:", run_folder)

## Create a folder for the adaptation results
adapt_folder = run_folder+"adapt/"
if not os.path.exists(adapt_folder):
    os.mkdir(adapt_folder)
# Out:
# No training. Loading data and results from: ./runs/03082024-024220-Toy/

# %%
#%%

# os.system(f'python dataset.py --split=test --savepath="{run_folder}" --seed="{seed*2}"')

if train == True and reuse_run_folder == False:
    # Run the dataset script to generate the data
    os.system(f'python dataset.py --split=train --savepath="{run_folder}" --seed="{seed}"')
    os.system(f'python dataset.py --split=test --savepath="{run_folder}" --seed="{seed*2}"')
if adapt == True and reuse_run_folder == False:
    os.system(f'python dataset.py --split=adapt --savepath="{adapt_folder}" --seed="{seed*3}"');
    os.system(f'python dataset.py --split=adapt_test --savepath="{adapt_folder}" --seed="{seed*3}"');
if adapt_huge == True and reuse_run_folder == False:
    os.system(f'python dataset.py --split=adapt_huge --savepath="{adapt_folder}" --seed="{seed*4}"');

# %%
#%%

## Define dataloader for training and validation
train_dataloader = DataLoader(run_folder+"train_data.npz", batch_size=-1, shuffle=True, key=seed)

nb_envs = train_dataloader.nb_envs
nb_trajs_per_env = train_dataloader.nb_trajs_per_env
nb_steps_per_traj = train_dataloader.nb_steps_per_traj
data_size = train_dataloader.data_size

val_dataloader = DataLoader(run_folder+"test_data.npz", shuffle=False)
# Out:
# WARNING: You did not provide a dataloader id. A new one has been generated: 104508
# WARNING: Note that this id used to distuinguish between adaptations to different environments.
# WARNING: batch_size must be between 0 and nb_trajs_per_env. Setting batch_size to maximum.
# WARNING: You did not provide a dataloader id. A new one has been generated: 104508
# WARNING: Note that this id used to distuinguish between adaptations to different environments.
# WARNING: batch_size must be between 0 and nb_trajs_per_env. Setting batch_size to maximum.

# %%
#%%

## Define model and loss function for the learner


def circular_pad_2d(x, pad_width):
    """ Circular padding for 2D arrays """
    if isinstance(pad_width, int):
        pad_width = ((pad_width, pad_width), (pad_width, pad_width))
    # return jnp.pad(x, pad_width, mode='wrap')

    if x.ndim == 2:
        return jnp.pad(x, pad_width, mode='wrap')
    else:
        zero_pad = [(0,0)]*(x.ndim-2)
        return jnp.pad(x, zero_pad+list(pad_width), mode='wrap')
    # return jnp.pad(x, pad_width, mode='wrap')


class Swish(eqx.Module):
    beta: jnp.ndarray
    def __init__(self, key=None):
        self.beta = jax.random.uniform(key, shape=(1,), minval=0.01, maxval=1.0)
    def __call__(self, x):
        return x * jax.nn.sigmoid(self.beta * x)

class Augmentation(eqx.Module):
    layers_data: list
    layers_context: list
    layers_shared: list
    activations: list

    def __init__(self, data_res, kernel_size, nb_comp_chans, nb_hidden_chans, context_size, key=None):
        keys = generate_new_keys(key, num=12)
        circular_pad = lambda x: circular_pad_2d(x, kernel_size//2)
        self.activations = [Swish(key=keys[i]) for i in range(0, 6)]

        self.layers_context = [eqx.nn.Linear(context_size, data_res*data_res*2, key=keys[3]), self.activations[0],
                                lambda x: jnp.stack(vec_to_mats(x, data_res, 2), axis=0),
                            circular_pad,
                            eqx.nn.Conv2d(2, nb_comp_chans, kernel_size, key=keys[0]), self.activations[5]]

        self.layers_data = [lambda x: jnp.stack(vec_to_mats(x, data_res, 2), axis=0),
                            circular_pad,
                            eqx.nn.Conv2d(2, nb_comp_chans, kernel_size, key=keys[0]), self.activations[4]]

        self.layers_shared = [circular_pad, 
                              eqx.nn.Conv2d(nb_comp_chans*2, nb_hidden_chans, kernel_size, key=keys[6]), self.activations[1],
                              circular_pad, 
                              eqx.nn.Conv2d(nb_hidden_chans, nb_hidden_chans, kernel_size, key=keys[7]), self.activations[2],
                              circular_pad, 
                              eqx.nn.Conv2d(nb_hidden_chans, nb_hidden_chans, kernel_size, key=keys[8]), self.activations[3],
                              circular_pad, 
                              eqx.nn.Conv2d(nb_hidden_chans, 2, kernel_size, key=keys[9]),
                            #   lambda x: x.flatten()]
                            lambda x: jnp.concatenate([x[0].flatten(), x[1].flatten()], axis=0)]

    def __call__(self, t, y, ctx):
        # return jnp.zeros_like(y)*ctx[0]

        for layer in self.layers_context:
            ctx = layer(ctx)

        for layer in self.layers_data:
            y = layer(y)

        y = jnp.concatenate([y, ctx], axis=0)
        # y = jnp.concatenate([y, y], axis=0)
        for layer in self.layers_shared:
            y = layer(y)

        return y * 1e-2
        # return jnp.zeros_like(y)




# # First-order Taylor approximation
# class ContextFlowVectorField(eqx.Module):
#     physics: eqx.Module
#     augmentation: eqx.Module

#     def __init__(self, augmentation, physics=None):
#         self.augmentation = augmentation
#         self.physics = physics

#     def __call__(self, t, x, ctxs):
#         if self.physics is None:
#             vf = lambda xi_: self.augmentation(t, x, xi_)
#         else:
#             vf = lambda xi_: self.physics(t, x, xi_) + self.augmentation(t, x, xi_)

#         gradvf = lambda xi_, xi: eqx.filter_jvp(vf, (xi_,), (xi-xi_,))[1]

#         ctx, ctx_ = ctxs
#         return vf(ctx_) + gradvf(ctx_, ctx)


## Second-order Taylor approximation
class ContextFlowVectorField(eqx.Module):
    physics: eqx.Module
    augmentation: eqx.Module

    def __init__(self, augmentation, physics=None):
        self.augmentation = augmentation
        self.physics = physics

    def __call__(self, t, x, ctxs):
        ctx, ctx_ = ctxs

        if self.physics is None:
            vf = lambda xi: self.augmentation(t, x, xi)
        else:
            vf = lambda xi: self.physics(t, x, xi) + self.augmentation(t, x, xi)

        return vf(ctx)                                                                  ## TODO disable CSM

        gradvf = lambda xi_: eqx.filter_jvp(vf, (xi_,), (ctx-xi_,))[1]
        scd_order_term = eqx.filter_jvp(gradvf, (ctx_,), (ctx-ctx_,))[1]

        # print("all operand types:", type(vf), type(gradvf), type(scd_order_term))
        return vf(ctx_) + 1.5*gradvf(ctx_) + 0.5*scd_order_term


augmentation = Augmentation(data_res=8, kernel_size=3, nb_comp_chans=8, nb_hidden_chans=64, context_size=context_size, key=seed)

# physics = Physics(key=seed)
physics = None

vectorfield = ContextFlowVectorField(augmentation, physics=physics)
print("\n\nTotal number of parameters in the model:", sum(x.size for x in jax.tree_util.tree_leaves(eqx.filter(vectorfield,eqx.is_array)) if x is not None), "\n\n")

contexts = ContextParams(nb_envs, context_size, key=None)

## Define a custom loss function here
def loss_fn_ctx(model, trajs, t_eval, ctx, all_ctx_s, key):

    # ind = jax.random.randint(key, shape=(context_pool_size,), minval=0, maxval=all_ctx_s.shape[0])
    # ind = jax.random.permutation(key, all_ctx_s.shape[0])[:context_pool_size]
    # ctx_s = all_ctx_s[ind, :]

    ## Select the two closes vectors in all_ctx_s to ctx
    dists = jnp.linalg.norm(all_ctx_s - ctx, axis=1)
    # ind = jnp.argsort(dists)[1:2]        ## ctx itself, and the closest context
    ind = jnp.argsort(dists)[:1]        ## ctx itself, and the closest context         ## TODO only use the closest for minimal compute
    ctx_s = all_ctx_s[ind, :]

    trajs_hat, nb_steps = jax.vmap(model, in_axes=(None, None, None, 0))(trajs[:, 0, :], t_eval, ctx, ctx_s)
    new_trajs = jnp.broadcast_to(trajs, trajs_hat.shape)

    term1 = jnp.mean((new_trajs-trajs_hat)**2)  ## reconstruction
    # term2 = jnp.mean(ctx**2)             ## regularisation
    term2 = jnp.mean(jnp.abs(ctx))             ## regularisation
    term3 = params_norm_squared(model)

    loss_val = term1 + 1e-3*term2 + 1e-3*term3
    # loss_val = jnp.nan_to_num(term1, nan=0.0, posinf=0.0, neginf=0.0)
    # loss_val = term1 + 1e-3*term2

    return loss_val, (jnp.sum(nb_steps)/ctx_s.shape[0], term1, term2)




learner = Learner(vectorfield, contexts, loss_fn_ctx, integrator, ivp_args, key=seed)
# Out:
# Total number of parameters in the model: 117502
#
#
# WARNING: No key provided for the context initialization. Initializing at 0.

# %%
#%%

## Define optimiser and traine the model

nb_total_epochs = nb_outer_steps_max * nb_inner_steps_max
sched_node = optax.piecewise_constant_schedule(init_value=init_lr,
                        boundaries_and_scales={nb_total_epochs//3:lr_factor, 2*nb_total_epochs//3:lr_factor})

sched_ctx = optax.piecewise_constant_schedule(init_value=init_lr,
                        boundaries_and_scales={nb_total_epochs//3:lr_factor, 2*nb_total_epochs//3:lr_factor})

opt_node = optax.adabelief(sched_node)
opt_ctx = optax.adabelief(sched_ctx)

trainer = Trainer(train_dataloader, learner, (opt_node, opt_ctx), key=seed)

# %%
#%%

trainer_save_path = run_folder if save_trainer == True else False
if train == True:
    # for propostion in [0.25, 0.5, 0.75]:
    for i, prop in enumerate(np.linspace(1.0, 1.0, 1)):
        # trainer.dataloader.int_cutoff = int(prop*nb_steps_per_traj)
        # trainer.train(nb_epochs=nb_epochs*(2**0), print_error_every=print_error_every*(2**0), update_context_every=1, save_path=trainer_save_path, key=seed, val_dataloader=val_dataloader, int_prop=prop)
        trainer.train_proximal(nb_outer_steps_max=nb_outer_steps_max, 
                               nb_inner_steps_max=nb_inner_steps_max, 
                               proximal_reg=proximal_beta, 
                               inner_tol_node=inner_tol_node, 
                               inner_tol_ctx=inner_tol_ctx,
                               print_error_every=print_error_every*(2**0), 
                               save_path=trainer_save_path, 
                               val_dataloader=val_dataloader, 
                               patience=early_stopping_patience,
                               int_prop=prop,
                               key=seed)
else:
    # print("\nNo training, attempting to load model and results from "+ run_folder +" folder ...\n")

    restore_folder = run_folder
    # restore_folder = "./runs/27012024-155719/finetune_193625/"
    trainer.restore_trainer(path=restore_folder)
# Out:
# No training, loading model and results from ./runs/03082024-024220-Toy/ folder ...

# %%
#%%

if finetune:
    # ## Finetune a trained model

    finetunedir = run_folder+"finetune_"+trainer.dataloader.data_id+"/"
    if not os.path.exists(finetunedir):
        os.mkdir(finetunedir)
    print("No training. Loading anctx_sd finetuning into:", finetunedir)

    trainer.dataloader.int_cutoff = nb_steps_per_traj

    opt_node = optax.adabelief(1e-7)
    opt_ctx = optax.adabelief(1e-7)
    trainer.opt_node, trainer.opt_ctx = opt_node, opt_ctx

    # trainer.opt_node_state = trainer.opt_node.init(eqx.filter(trainer.learner.neuralode, eqx.is_array))
    # trainer.opt_ctx_state = trainer.opt_ctx.init(trainer.learner.contexts)

    trainer.train(nb_epochs=24000, print_error_every=1000, update_context_every=1, save_path=finetunedir, key=seed)

# %%
#%%

## Test and visualise the results on a test dataloader

test_dataloader = DataLoader(run_folder+"test_data.npz", shuffle=False)
visualtester = VisualTester(trainer)
# ans = visualtester.trainer.nb_steps_node
# print(ans.shape)

ind_crit = visualtester.test(test_dataloader, int_cutoff=1.0)
print("\nPer-environment IND scores:", ind_crit[1])

if finetune:
    savefigdir = finetunedir+"results_in_domain.png"
else:
    savefigdir = run_folder+"results_in_domain.png"
visualtester.visualize(test_dataloader, int_cutoff=1.0, save_path=savefigdir);
# Out:
# WARNING: You did not provide a dataloader id. A new one has been generated: 104510
# WARNING: Note that this id used to distuinguish between adaptations to different environments.
# WARNING: batch_size must be between 0 and nb_trajs_per_env. Setting batch_size to maximum.
# WARNING: No key provided, using time as seed
# ==  Begining in-domain testing ... ==
#     Number of training environments: 9
#     Final length of the training trajectories: 20
#     Length of the testing trajectories: 20
# Test Score (In-Domain): 0.34643993
#
#
# Per-environment IND scores: [0.25303328 0.444034   1.6476041  0.10663345 0.28733903 0.2486746
#  0.03417477 0.03909059 0.05737559]
# ==  Begining in-domain visualisation ... ==
#     Environment id: 7
#     Trajectory id: 27
#     Visualized dimensions: (0, 1)
#     Final length of the training trajectories: 20
#     Length of the testing trajectories: 20
# Testing finished. Figure saved in: ./runs/03082024-024220-Toy/results_in_domain.png

# %%
#%%

## Custom Gray-Scott trajectory visualiser
if finetune:
    savefigdir = finetunedir+"results_2D_ind.png"
else:
    savefigdir = run_folder+"results_2D_ind.png"
# visualtester.visualize2D(test_dataloader, int_cutoff=1.0, res=8, nb_plot_timesteps=10, save_path=savefigdir);
# visualtester.visualize2D(train_dataloader, int_cutoff=1.0, res=8, nb_plot_timesteps=10, save_path=run_folder+"results_2D_ind_train.png");

# %%
#%%

# len(trainer.losses_node

# ## Run and get the contexts
# for i in range(nb_envs):
#     ctx = trainer.learner.contexts.params[i]
#     # print(ctx)
#     param = ctx
#     for layer in trainer.learner.physics.layers_context:
#         param = layer(param)
#         # print("Context", ctx, "     Param", param)
#     param = jnp.abs(param)
#     print("Param:", param)

# %%
#%%

## If the nohup.log file exists, copy it to the run folder
try:
    __IPYTHON__ ## in a jupyter notebook
except NameError:
    if os.path.exists("nohup.log"):
        if finetune == True:
            os.system(f"cp nohup.log {finetunedir}")
            ## Open the results_in_domain in the terminal
            os.system(f"open {finetunedir}results_in_domain.png")
        else:
            os.system(f"cp nohup.log {run_folder}")
            # os.system(f"open {run_folder}results_in_domain.png")

# %%
#%%

## Give the dataloader an id to help with restoration later on

adapt_dataloader = DataLoader(adapt_folder+"adapt_data.npz", adaptation=True, data_id="170846", key=seed)
adapt_dataloader_test = DataLoader(adapt_folder+"adapt_data_test.npz", adaptation=True, data_id="1708460", key=seed)

# sched_ctx_new = optax.piecewise_constant_schedule(init_value=1e-5,
#                         boundaries_and_scales={int(nb_epochs_adapt*0.25):1.,
#                                                 int(nb_epochs_adapt*0.5):0.1,
#                                                 int(nb_epochs_adapt*0.75):1.})
# sched_ctx_new = optax.piecewise_constant_schedule(init_value=init_lr,
#                         boundaries_and_scales={nb_total_epochs//3:0.1, 2*nb_total_epochs//3:1.0})
sched_ctx_new = 5e-4
opt_adapt = optax.adabelief(sched_ctx_new)

if adapt == True:
    # trainer.adapt_sequential(adapt_dataloader, nb_epochs=nb_epochs_adapt, optimizer=opt_adapt, print_error_every=print_error_every**2, save_path=adapt_folder)
    trainer.adapt(adapt_dataloader, nb_epochs=nb_epochs_adapt*2, optimizer=opt_adapt, print_error_every=print_error_every, save_path=adapt_folder)
else:
    print("save_id:", adapt_dataloader.data_id)

    trainer.restore_adapted_trainer(path=adapt_folder, data_loader=adapt_dataloader)
# Out:
# WARNING: batch_size must be between 0 and nb_trajs_per_env. Setting batch_size to maximum.
# WARNING: batch_size must be between 0 and nb_trajs_per_env. Setting batch_size to maximum.
# WARNING: No key provided for the context initialization. Initializing at 0.
#
#
# === Beginning adaptation ... ===
#     Number of examples in a batch: 1
#     Number of train steps per epoch: 1
#     Number of training epochs: 3000
#     Total number of training steps: 3000
# WARNING: No key provided, using time as seed
#
# Compiling function "train_step" for context ...
# Shapes of elements in a batch: (16, 1, 20, 128) (20,)
#     Epoch:     0     LossContext: 3.08162355
#     Epoch:     1     LossContext: 3.04661345
#     Epoch:     2     LossContext: 3.00753975
#     Epoch:     3     LossContext: 2.96623254
#     Epoch:    10     LossContext: 2.53810072
#     Epoch:    20     LossContext: 2.19434094
#     Epoch:    30     LossContext: 1.79027593
#     Epoch:    40     LossContext: 1.65400624
#     Epoch:    50     LossContext: 1.60408235
#     Epoch:    60     LossContext: 1.59462416
#     Epoch:    70     LossContext: 1.59208834
#     Epoch:    80     LossContext: 1.58610940
#     Epoch:    90     LossContext: 1.58826947
#     Epoch:   100     LossContext: 1.58770490
#     Epoch:   110     LossContext: 1.58371329
#     Epoch:   120     LossContext: 1.58831787
#     Epoch:   130     LossContext: 1.58502316
#     Epoch:   140     LossContext: 1.58118832
#     Epoch:   150     LossContext: 1.58045220
#     Epoch:   160     LossContext: 1.58042610
#     Epoch:   170     LossContext: 1.58299184
#     Epoch:   180     LossContext: 1.57659221
#     Epoch:   190     LossContext: 1.57693195
#     Epoch:   200     LossContext: 1.57320631
#     Epoch:   210     LossContext: 1.57457030
#     Epoch:   220     LossContext: 1.57238686
#     Epoch:   230     LossContext: 1.57221508
#     Epoch:   240     LossContext: 1.57056272
#     Epoch:   250     LossContext: 1.57226205
#     Epoch:   260     LossContext: 1.57299733
#     Epoch:   270     LossContext: 1.57214355
#     Epoch:   280     LossContext: 1.56940830
#     Epoch:   290     LossContext: 1.57277751
#     Epoch:   300     LossContext: 1.56762981
#     Epoch:   310     LossContext: 1.56898832
#     Epoch:   320     LossContext: 1.56990027
#     Epoch:   330     LossContext: 1.56861281
#     Epoch:   340     LossContext: 1.56654525
#     Epoch:   350     LossContext: 1.56716478
#     Epoch:   360     LossContext: 1.56515074
#     Epoch:   370     LossContext: 1.56521082
#     Epoch:   380     LossContext: 1.56245625
#     Epoch:   390     LossContext: 1.56693339
#     Epoch:   400     LossContext: 1.56348872
#     Epoch:   410     LossContext: 1.56447291
#     Epoch:   420     LossContext: 1.56396914
#     Epoch:   430     LossContext: 1.56511784
#     Epoch:   440     LossContext: 1.56421614
#     Epoch:   450     LossContext: 1.56220114
#     Epoch:   460     LossContext: 1.56931579
#     Epoch:   470     LossContext: 1.56335616
#     Epoch:   480     LossContext: 1.56753278
#     Epoch:   490     LossContext: 1.45792830
#     Epoch:   500     LossContext: 1.39394212
#     Epoch:   510     LossContext: 1.36626852
#     Epoch:   520     LossContext: 1.35614741
#     Epoch:   530     LossContext: 1.35189354
#     Epoch:   540     LossContext: 1.35497665
#     Epoch:   550     LossContext: 1.35373330
#     Epoch:   560     LossContext: 1.35450649
#     Epoch:   570     LossContext: 1.35531771
#     Epoch:   580     LossContext: 1.35287952
#     Epoch:   590     LossContext: 1.35397601
#     Epoch:   600     LossContext: 1.34604502
#     Epoch:   610     LossContext: 1.35275137
#     Epoch:   620     LossContext: 1.35212088
#     Epoch:   630     LossContext: 1.30466151
#     Epoch:   640     LossContext: 1.25644016
#     Epoch:   650     LossContext: 1.21250582
#     Epoch:   660     LossContext: 1.19109535
#     Epoch:   670     LossContext: 1.19003141
#     Epoch:   680     LossContext: 1.18954921
#     Epoch:   690     LossContext: 1.18826926
#     Epoch:   700     LossContext: 1.19013405
#     Epoch:   710     LossContext: 1.19309974
#     Epoch:   720     LossContext: 1.19402409
#     Epoch:   730     LossContext: 1.18653142
#     Epoch:   740     LossContext: 1.18805766
#     Epoch:   750     LossContext: 1.18733048
#     Epoch:   760     LossContext: 1.18757987
#     Epoch:   770     LossContext: 1.18725538
#     Epoch:   780     LossContext: 1.18765175
#     Epoch:   790     LossContext: 1.18615675
#     Epoch:   800     LossContext: 1.18467712
#     Epoch:   810     LossContext: 1.18180513
#     Epoch:   820     LossContext: 1.19485891
#     Epoch:   830     LossContext: 1.18994546
#     Epoch:   840     LossContext: 1.18431973
#     Epoch:   850     LossContext: 1.18150973
#     Epoch:   860     LossContext: 1.18397593
#     Epoch:   870     LossContext: 1.18275738
#     Epoch:   880     LossContext: 1.18125534
#     Epoch:   890     LossContext: 1.18157673
#     Epoch:   900     LossContext: 1.18158412
#     Epoch:   910     LossContext: 1.18173885
#     Epoch:   920     LossContext: 1.18254280
#     Epoch:   930     LossContext: 1.18607664
#     Epoch:   940     LossContext: 1.18728185
#     Epoch:   950     LossContext: 1.19059634
#     Epoch:   960     LossContext: 1.18444431
#     Epoch:   970     LossContext: 1.14081049
#     Epoch:   980     LossContext: 1.08413959
#     Epoch:   990     LossContext: 1.07732153
#     Epoch:  1000     LossContext: 1.06155241
#     Epoch:  1010     LossContext: 1.06477523
#     Epoch:  1020     LossContext: 1.06226230
#     Epoch:  1030     LossContext: 1.06236243
#     Epoch:  1040     LossContext: 1.05928969
#     Epoch:  1050     LossContext: 1.06056786
#     Epoch:  1060     LossContext: 1.05796671
#     Epoch:  1070     LossContext: 1.05627406
#     Epoch:  1080     LossContext: 1.05753303
#     Epoch:  1090     LossContext: 1.06239796
#     Epoch:  1100     LossContext: 1.05905020
#     Epoch:  1110     LossContext: 1.05742371
#     Epoch:  1120     LossContext: 1.05770063
#     Epoch:  1130     LossContext: 1.05596304
#     Epoch:  1140     LossContext: 1.05694640
#     Epoch:  1150     LossContext: 1.05989718
#     Epoch:  1160     LossContext: 1.05901146
#     Epoch:  1170     LossContext: 1.06404388
#     Epoch:  1180     LossContext: 1.05980146
#     Epoch:  1190     LossContext: 1.05482936
#     Epoch:  1200     LossContext: 1.05680156
#     Epoch:  1210     LossContext: 1.05899370
#     Epoch:  1220     LossContext: 1.06234300
#     Epoch:  1230     LossContext: 1.06104505
#     Epoch:  1240     LossContext: 1.05315030
#     Epoch:  1250     LossContext: 1.05664241
#     Epoch:  1260     LossContext: 1.05317962
#     Epoch:  1270     LossContext: 1.05583596
#     Epoch:  1280     LossContext: 1.05452156
#     Epoch:  1290     LossContext: 1.05425584
#     Epoch:  1300     LossContext: 1.05321229
#     Epoch:  1310     LossContext: 1.05504167
#     Epoch:  1320     LossContext: 1.05483174
#     Epoch:  1330     LossContext: 1.05486035
#     Epoch:  1340     LossContext: 1.05449164
#     Epoch:  1350     LossContext: 1.05396533
#     Epoch:  1360     LossContext: 1.05503678
#     Epoch:  1370     LossContext: 1.05625284
#     Epoch:  1380     LossContext: 1.05471039
#     Epoch:  1390     LossContext: 1.05875170
#     Epoch:  1400     LossContext: 1.05652559
#     Epoch:  1410     LossContext: 1.06154203
#     Epoch:  1420     LossContext: 1.05357909
#     Epoch:  1430     LossContext: 1.05417836
#     Epoch:  1440     LossContext: 1.05275762
#     Epoch:  1450     LossContext: 1.05388868
#     Epoch:  1460     LossContext: 1.05450189
#     Epoch:  1470     LossContext: 1.05342078
#     Epoch:  1480     LossContext: 1.05530632
#     Epoch:  1490     LossContext: 1.05462384
#     Epoch:  1500     LossContext: 1.05547106
#     Epoch:  1510     LossContext: 1.05372262
#     Epoch:  1520     LossContext: 1.05321419
#     Epoch:  1530     LossContext: 1.05559516
#     Epoch:  1540     LossContext: 1.05478477
#     Epoch:  1550     LossContext: 1.05356789
#     Epoch:  1560     LossContext: 1.05276585
#     Epoch:  1570     LossContext: 1.05335963
#     Epoch:  1580     LossContext: 1.05263662
#     Epoch:  1590     LossContext: 1.05357361
#     Epoch:  1600     LossContext: 1.05935144
#     Epoch:  1610     LossContext: 1.05870199
#     Epoch:  1620     LossContext: 1.06159616
#     Epoch:  1630     LossContext: 1.05943608
#     Epoch:  1640     LossContext: 1.05498028
#     Epoch:  1650     LossContext: 1.05335379
#     Epoch:  1660     LossContext: 1.05313635
#     Epoch:  1670     LossContext: 1.05590057
#     Epoch:  1680     LossContext: 1.05738723
#     Epoch:  1690     LossContext: 1.05533218
#     Epoch:  1700     LossContext: 1.05375564
#     Epoch:  1710     LossContext: 1.05640578
#     Epoch:  1720     LossContext: 1.05318213
#     Epoch:  1730     LossContext: 1.05406475
#     Epoch:  1740     LossContext: 1.05209613
#     Epoch:  1750     LossContext: 1.05346489
#     Epoch:  1760     LossContext: 1.05440891
#     Epoch:  1770     LossContext: 1.05367684
#     Epoch:  1780     LossContext: 1.05473995
#     Epoch:  1790     LossContext: 1.05395389
#     Epoch:  1800     LossContext: 1.05441928
#     Epoch:  1810     LossContext: 1.05861557
#     Epoch:  1820     LossContext: 1.05529857
#     Epoch:  1830     LossContext: 1.05795515
#     Epoch:  1840     LossContext: 1.05795193
#     Epoch:  1850     LossContext: 1.05388856
#     Epoch:  1860     LossContext: 1.05276000
#     Epoch:  1870     LossContext: 1.05402136
#     Epoch:  1880     LossContext: 1.05315042
#     Epoch:  1890     LossContext: 1.05631304
#     Epoch:  1900     LossContext: 1.05603230
#     Epoch:  1910     LossContext: 1.05436850
#     Epoch:  1920     LossContext: 1.05291605
#     Epoch:  1930     LossContext: 1.05391049
#     Epoch:  1940     LossContext: 1.05304110
#     Epoch:  1950     LossContext: 1.05308378
#     Epoch:  1960     LossContext: 1.05397213
#     Epoch:  1970     LossContext: 1.05316222
#     Epoch:  1980     LossContext: 1.05221355
#     Epoch:  1990     LossContext: 1.05301285
#     Epoch:  2000     LossContext: 1.05262959
#     Epoch:  2010     LossContext: 1.05473137
#     Epoch:  2020     LossContext: 1.05570316
#     Epoch:  2030     LossContext: 1.05538654
#     Epoch:  2040     LossContext: 1.05405569
#     Epoch:  2050     LossContext: 1.05743885
#     Epoch:  2060     LossContext: 1.05414772
#     Epoch:  2070     LossContext: 1.06097949
#     Epoch:  2080     LossContext: 1.05305338
#     Epoch:  2090     LossContext: 1.05339146
#     Epoch:  2100     LossContext: 1.05394626
#     Epoch:  2110     LossContext: 1.05231583
#     Epoch:  2120     LossContext: 1.05421662
#     Epoch:  2130     LossContext: 1.05290532
#     Epoch:  2140     LossContext: 1.05297124
#     Epoch:  2150     LossContext: 1.05408442
#     Epoch:  2160     LossContext: 1.07125723
#     Epoch:  2170     LossContext: 1.05966520
#     Epoch:  2180     LossContext: 1.05463505
#     Epoch:  2190     LossContext: 1.05310941
#     Epoch:  2200     LossContext: 1.05895734
#     Epoch:  2210     LossContext: 1.05933070
#     Epoch:  2220     LossContext: 1.05521536
#     Epoch:  2230     LossContext: 1.05401921
#     Epoch:  2240     LossContext: 1.05255175
#     Epoch:  2250     LossContext: 1.05015731
#     Epoch:  2260     LossContext: 1.05267859
#     Epoch:  2270     LossContext: 1.05603766
#     Epoch:  2280     LossContext: 1.04964268
#     Epoch:  2290     LossContext: 1.06120479
#     Epoch:  2300     LossContext: 1.05998516
#     Epoch:  2310     LossContext: 1.05724454
#     Epoch:  2320     LossContext: 1.05652928
#     Epoch:  2330     LossContext: 1.05407655
#     Epoch:  2340     LossContext: 1.05401278
#     Epoch:  2350     LossContext: 1.05122089
#     Epoch:  2360     LossContext: 1.05292869
#     Epoch:  2370     LossContext: 1.05247676
#     Epoch:  2380     LossContext: 1.05406916
#     Epoch:  2390     LossContext: 1.05358779
#     Epoch:  2400     LossContext: 1.05216753
#     Epoch:  2410     LossContext: 1.05370307
#     Epoch:  2420     LossContext: 1.05381489
#     Epoch:  2430     LossContext: 1.05346107
#     Epoch:  2440     LossContext: 1.05254352
#     Epoch:  2450     LossContext: 1.05424309
#     Epoch:  2460     LossContext: 1.05362356
#     Epoch:  2470     LossContext: 1.05228102
#     Epoch:  2480     LossContext: 1.05233085
#     Epoch:  2490     LossContext: 1.05427980
#     Epoch:  2500     LossContext: 1.05692351
#     Epoch:  2510     LossContext: 1.05835354
#     Epoch:  2520     LossContext: 1.05373144
#     Epoch:  2530     LossContext: 1.05259156
#     Epoch:  2540     LossContext: 1.05455804
#     Epoch:  2550     LossContext: 1.05300939
#     Epoch:  2560     LossContext: 1.05436110
#     Epoch:  2570     LossContext: 1.05328560
#     Epoch:  2580     LossContext: 1.05313492
#     Epoch:  2590     LossContext: 1.05179846
#     Epoch:  2600     LossContext: 1.05322814
#     Epoch:  2610     LossContext: 1.05569839
#     Epoch:  2620     LossContext: 1.05222893
#     Epoch:  2630     LossContext: 1.05275071
#     Epoch:  2640     LossContext: 1.05313361
#     Epoch:  2650     LossContext: 1.05436718
#     Epoch:  2660     LossContext: 1.05408120
#     Epoch:  2670     LossContext: 1.05355883
#     Epoch:  2680     LossContext: 1.05239248
#     Epoch:  2690     LossContext: 1.05285597
#     Epoch:  2700     LossContext: 1.05336499
#     Epoch:  2710     LossContext: 1.05252457
#     Epoch:  2720     LossContext: 1.05271959
#     Epoch:  2730     LossContext: 1.05818689
#     Epoch:  2740     LossContext: 1.05574822
#     Epoch:  2750     LossContext: 1.04993677
#     Epoch:  2760     LossContext: 1.05788350
#     Epoch:  2770     LossContext: 1.05664134
#     Epoch:  2780     LossContext: 1.04229069
#     Epoch:  2790     LossContext: 1.04143798
#     Epoch:  2800     LossContext: 1.04031301
#     Epoch:  2810     LossContext: 1.03919363
#     Epoch:  2820     LossContext: 1.03972149
#     Epoch:  2830     LossContext: 1.03996205
#     Epoch:  2840     LossContext: 1.03970361
#     Epoch:  2850     LossContext: 1.04160571
#     Epoch:  2860     LossContext: 1.04011953
#     Epoch:  2870     LossContext: 1.04345202
#     Epoch:  2880     LossContext: 1.04239416
#     Epoch:  2890     LossContext: 1.03972447
#     Epoch:  2900     LossContext: 1.04215503
#     Epoch:  2910     LossContext: 1.04195511
#     Epoch:  2920     LossContext: 1.03852022
#     Epoch:  2930     LossContext: 1.03788900
#     Epoch:  2940     LossContext: 1.03909409
#     Epoch:  2950     LossContext: 1.04439712
#     Epoch:  2960     LossContext: 1.04307055
#     Epoch:  2970     LossContext: 1.04680276
#     Epoch:  2980     LossContext: 1.04110980
#     Epoch:  2990     LossContext: 1.04155779
#     Epoch:  2999     LossContext: 1.04231954
#
# Total gradient descent adaptation time: 0 hours 4 mins 17 secs
#
# Saving adaptation parameters into ./runs/03082024-024220-Toy/adapt/ folder with id 170846 ...

# %%
#%%

ood_crit = visualtester.test(adapt_dataloader_test, int_cutoff=1.0)      ## It's the same visualtester as before during training. It knows trainer

visualtester.visualize(adapt_dataloader, int_cutoff=1.0, save_path=adapt_folder+"results_ood.png");


print("\nPer-environment OOD scores:", ood_crit[1])
# Out:
# ==  Begining out-of-distribution testing ... ==
#     Number of training environments: 9
#     Number of adaptation environments: 16
#     Final length of the training trajectories: 20
#     Length of the testing trajectories: 20
# Test Score (OOD): 1.2148576
#
# ==  Begining out-of-distribution visualisation ... ==
#     Environment id: 4
#     Trajectory id: 0
#     Visualized dimensions: (0, 1)
#     Final length of the training trajectories: 20
#     Length of the testing trajectories: 20
# Testing finished. Figure saved in: ./runs/03082024-024220-Toy/adapt/results_ood.png
#
# Per-environment OOD scores: [3.0708961  3.6906803  3.5473933  4.3747463  0.06222539 0.21302488
#  0.30194157 0.40535074 0.03862525 0.03588235 0.12391182 3.2825727
#  0.02805804 0.03988893 0.05587174 0.1666515 ]

# %%
#%%

## If the nohup.log file exists, copy it to the run folder
try:
    __IPYTHON__ ## in a jupyter notebook
except NameError:
    if os.path.exists("nohup.log"):
        if finetune == True:
            os.system(f"cp nohup.log {finetunedir}")
            ## Open the results_in_domain in the terminal
            os.system(f"open {finetunedir}results_in_domain.png")
        else:
            os.system(f"cp nohup.log {run_folder}")
            # os.system(f"open {run_folder}results_in_domain.png")

# %%
#%%

# eqx.tree_deserialise_leaves(run_folder+"contexts.eqx", learner.contexts)

# %%
#%%

#### Generate data for analysis


# ## We want to store 3 values in a CSV file: "seed", "ind_crit", and "ood_crit", into the test_scores.csv file


# print("\nFull evaluation of the model on 10 random seeds\n", flush=True)

# # First, check if the file exists. If not, create it and write the header
# if not os.path.exists(run_folder+'analysis'):
#     os.mkdir(run_folder+'analysis')

# csv_file = run_folder+'analysis/test_scores.csv'
# if not os.path.exists(csv_file):
#     os.system(f"touch {csv_file}")

# with open(csv_file, 'r') as f:
#     lines = f.readlines()
#     if len(lines) == 0:
#         with open(csv_file, 'w') as f:
#             f.write("seed,ind_crit,ood_crit\n")


# ## Get results on test and adaptation datasets, then append them to the csv

# np.random.seed(seed)
# seeds = np.random.randint(0, 10000, 10)
# for seed in seeds:
# # for seed in range(8000, 6*10**3, 10):
#     os.system(f'python dataset.py --split=test --savepath="{run_folder}" --seed="{seed*2}" --verbose=0')
#     os.system(f'python dataset.py --split=adapt --savepath="{adapt_folder}" --seed="{seed*3}" --verbose=0')

#     test_dataloader = DataLoader(run_folder+"test_data.npz", shuffle=False, batch_size=1, data_id="082026")
#     adapt_test_dataloader = DataLoader(adapt_folder+"adapt_data.npz", adaptation=True, batch_size=1, key=seed, data_id="082026")

#     ind_crit, _ = visualtester.test(test_dataloader, int_cutoff=1.0, verbose=False)
#     ood_crit, _ = visualtester.test(adapt_test_dataloader, int_cutoff=1.0, verbose=False)

#     with open(csv_file, 'a') as f:
#         f.write(f"{seed},{ind_crit},{ood_crit}\n")


# ## Print the mean and stds of the scores
# import pandas as pd
# pd.set_option('display.float_format', '{:.2e}'.format)
# test_scores = pd.read_csv(csv_file).describe()
# print(test_scores.iloc[:3])
