# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="paper")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:37
#      35 import seaborn as sns
#      36 import numpy as np
# ---> 37 sns.set_theme(style="paper")
#      38 f, ax = plt.subplots(figsize=(10, 6))
#      40 ## Plot the in-domain loss vs the pool size
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:120, in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#      84 """
#      85 Set aspects of the visual theme for all matplotlib and seaborn plots.
#      86
#    (...)
#     117
#     118 """
#     119 set_context(context, font_scale)
# --> 120 set_style(style, rc={"font.family": font})
#     121 set_palette(palette, color_codes=color_codes)
#     122 if rc is not None:
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:331, in set_style(style, rc)
#     303 def set_style(style=None, rc=None):
#     304     """
#     305     Set the parameters that control the general style of the plots.
#     306
#    (...)
#     329
#     330     """
# --> 331     style_object = axes_style(style, rc)
#     332     mpl.rcParams.update(style_object)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:185, in axes_style(style, rc)
#     183 styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     184 if style not in styles:
# --> 185     raise ValueError(f"style must be one of {', '.join(styles)}")
#     187 # Define colors here
#     188 dark_gray = ".15"
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("notebook")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax.twinx()
sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain Loss")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="blue", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="magenta", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="darkpurple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:42
#      39 f, ax = plt.subplots(figsize=(10, 6))
#      41 ## Plot the in-domain loss vs the pool size
# ---> 42 sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="darkpurple", label="In-Domain")
#      44 ## Plot the adaptation losses on a twin axis
#      45 ax2 = ax
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:2516, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, color, palette, hue_norm, markers, linestyles, dodge, log_scale, native_scale, orient, capsize, formatter, legend, err_kws, ci, errwidth, join, scale, ax, **kwargs)
#    2513 p._point_kwargs_backcompat(scale, join, kwargs)
#    2514 err_kws, capsize = p._err_kws_backcompat(err_kws, None, errwidth, capsize)
# -> 2516 p.plot_points(
#    2517     aggregator=aggregator,
#    2518     markers=markers,
#    2519     linestyles=linestyles,
#    2520     dodge=dodge,
#    2521     color=color,
#    2522     capsize=capsize,
#    2523     err_kws=err_kws,
#    2524     plot_kws=kwargs,
#    2525 )
#    2527 p._add_axis_labels(ax)
#    2528 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:1231, in _CategoricalPlotter.plot_points(self, aggregator, markers, linestyles, dodge, color, capsize, err_kws, plot_kws)
#    1224 sub_kws = plot_kws.copy()
#    1225 sub_kws.update(
#    1226     marker=markers[sub_vars.get("hue")],
#    1227     linestyle=linestyles[sub_vars.get("hue")],
#    1228     color=self._hue_map(sub_vars["hue"]) if "hue" in sub_vars else color,
#    1229 )
# -> 1231 line, = ax.plot(agg_data["x"], agg_data["y"], **sub_kws)
#    1233 sub_err_kws = err_kws.copy()
#    1234 line_props = line.properties()
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/lines.py:376, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     373 self.set_drawstyle(drawstyle)
#     375 self._color = None
# --> 376 self.set_color(color)
#     377 if marker is None:
#     378     marker = 'none'  # Default.
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/lines.py:1061, in Line2D.set_color(self, color)
#    1053 def set_color(self, color):
#    1054     """
#    1055     Set the color of the line.
#    1056
#    (...)
#    1059     color : color
#    1060     """
# -> 1061     mcolors._check_color_like(color=color)
#    1062     self._color = color
#    1063     self.stale = True
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/colors.py:246, in _check_color_like(**kwargs)
#     244 for k, v in kwargs.items():
#     245     if not is_color_like(v):
# --> 246         raise ValueError(f"{v!r} is not a valid value for {k}")
#
# ValueError: 'darkpurple' is not a valid value for color

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="dark-purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:42
#      39 f, ax = plt.subplots(figsize=(10, 6))
#      41 ## Plot the in-domain loss vs the pool size
# ---> 42 sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="dark-purple", label="In-Domain")
#      44 ## Plot the adaptation losses on a twin axis
#      45 ax2 = ax
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:2516, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, color, palette, hue_norm, markers, linestyles, dodge, log_scale, native_scale, orient, capsize, formatter, legend, err_kws, ci, errwidth, join, scale, ax, **kwargs)
#    2513 p._point_kwargs_backcompat(scale, join, kwargs)
#    2514 err_kws, capsize = p._err_kws_backcompat(err_kws, None, errwidth, capsize)
# -> 2516 p.plot_points(
#    2517     aggregator=aggregator,
#    2518     markers=markers,
#    2519     linestyles=linestyles,
#    2520     dodge=dodge,
#    2521     color=color,
#    2522     capsize=capsize,
#    2523     err_kws=err_kws,
#    2524     plot_kws=kwargs,
#    2525 )
#    2527 p._add_axis_labels(ax)
#    2528 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:1231, in _CategoricalPlotter.plot_points(self, aggregator, markers, linestyles, dodge, color, capsize, err_kws, plot_kws)
#    1224 sub_kws = plot_kws.copy()
#    1225 sub_kws.update(
#    1226     marker=markers[sub_vars.get("hue")],
#    1227     linestyle=linestyles[sub_vars.get("hue")],
#    1228     color=self._hue_map(sub_vars["hue"]) if "hue" in sub_vars else color,
#    1229 )
# -> 1231 line, = ax.plot(agg_data["x"], agg_data["y"], **sub_kws)
#    1233 sub_err_kws = err_kws.copy()
#    1234 line_props = line.properties()
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/lines.py:376, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     373 self.set_drawstyle(drawstyle)
#     375 self._color = None
# --> 376 self.set_color(color)
#     377 if marker is None:
#     378     marker = 'none'  # Default.
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/lines.py:1061, in Line2D.set_color(self, color)
#    1053 def set_color(self, color):
#    1054     """
#    1055     Set the color of the line.
#    1056
#    (...)
#    1059     color : color
#    1060     """
# -> 1061     mcolors._check_color_like(color=color)
#    1062     self._color = color
#    1063     self.stale = True
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/colors.py:246, in _check_color_like(**kwargs)
#     244 for k, v in kwargs.items():
#     245     if not is_color_like(v):
# --> 246         raise ValueError(f"{v!r} is not a valid value for {k}")
#
# ValueError: 'dark-purple' is not a valid value for color

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")







ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="x", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="sqaure", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/markers.py:335, in MarkerStyle._set_marker(self, marker)
#     334 try:
# --> 335     Path(marker)
#     336     self._marker_function = self._set_vertices
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/cbook.py:1345, in _to_unmasked_float_array(x)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# ValueError: could not convert string to float: 'sqaure'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:42
#      39 f, ax = plt.subplots(figsize=(10, 6))
#      41 ## Plot the in-domain loss vs the pool size
# ---> 42 sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="sqaure", color="purple", label="In-Domain")
#      44 ## Plot the adaptation losses on a twin axis
#      45 ax2 = ax
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:2516, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, color, palette, hue_norm, markers, linestyles, dodge, log_scale, native_scale, orient, capsize, formatter, legend, err_kws, ci, errwidth, join, scale, ax, **kwargs)
#    2513 p._point_kwargs_backcompat(scale, join, kwargs)
#    2514 err_kws, capsize = p._err_kws_backcompat(err_kws, None, errwidth, capsize)
# -> 2516 p.plot_points(
#    2517     aggregator=aggregator,
#    2518     markers=markers,
#    2519     linestyles=linestyles,
#    2520     dodge=dodge,
#    2521     color=color,
#    2522     capsize=capsize,
#    2523     err_kws=err_kws,
#    2524     plot_kws=kwargs,
#    2525 )
#    2527 p._add_axis_labels(ax)
#    2528 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:1231, in _CategoricalPlotter.plot_points(self, aggregator, markers, linestyles, dodge, color, capsize, err_kws, plot_kws)
#    1224 sub_kws = plot_kws.copy()
#    1225 sub_kws.update(
#    1226     marker=markers[sub_vars.get("hue")],
#    1227     linestyle=linestyles[sub_vars.get("hue")],
#    1228     color=self._hue_map(sub_vars["hue"]) if "hue" in sub_vars else color,
#    1229 )
# -> 1231 line, = ax.plot(agg_data["x"], agg_data["y"], **sub_kws)
#    1233 sub_err_kws = err_kws.copy()
#    1234 line_props = line.properties()
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/axes/_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/lines.py:380, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     378     marker = 'none'  # Default.
#     379 if not isinstance(marker, MarkerStyle):
# --> 380     self._marker = MarkerStyle(marker, fillstyle)
#     381 else:
#     382     self._marker = marker
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/markers.py:338, in MarkerStyle._set_marker(self, marker)
#     336         self._marker_function = self._set_vertices
#     337     except ValueError as err:
# --> 338         raise ValueError(
#     339             f'Unrecognized marker style {marker!r}') from err
#     341 if not isinstance(marker, MarkerStyle):
#     342     self._marker = marker
#
# ValueError: Unrecognized marker style 'sqaure'

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("talk")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="s", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="s", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="s", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

# df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="s", color="purple", label="In-Domain")

## Plot the adaptation losses on a twin axis
ax2 = ax
# sns.pointplot(data=df_1, x="pool_size", y="ood_seq", ax=ax2, markers="o", color="red", label="OOD Loss (Sequential)")
# sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD Loss (Batch)")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax2, markers="o", color="green", label="OOD")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(10, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="s", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
ax2 = ax.twinx()
sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="x", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="x", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(12, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
ax2 = ax.twinx()
sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="x", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="x", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(12, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
ax2 = ax.twinx()
sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(12, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
ax2 = ax.twinx()
sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, ax = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")



ax.set(xlabel='Context Pool Size', ylabel='MSE')



ax.legend()
ax2.legend()

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax, ax2) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='MSE')

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:42
#      40 sns.set_theme(style="white")
#      41 sns.set_context("poster")
# ---> 42 f, (ax, ax2) = plt.subplots(figsize=(7, 6))
#      44 ## Plot the in-domain loss vs the pool size
#      45 sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
#
# TypeError: cannot unpack non-iterable Axes object

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='MSE')

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='MSE')

## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:64
#      61 ax2.set(xlabel='Context Pool Size', ylabel='MSE')
#      63 ## Save figure as a pdf
# ---> 64 plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight', ax=ax)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# TypeError: FigureCanvasPdf.print_pdf() got an unexpected keyword argument 'ax'

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='MSE')

## Save figure as a pdf
ax.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:64
#      61 ax2.set(xlabel='Context Pool Size', ylabel='MSE')
#      63 ## Save figure as a pdf
# ---> 64 ax.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')
#
# AttributeError: 'Axes' object has no attribute 'savefig'

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='MSE')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='Wall Time (min)')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="In-Domain Training", ax=ax2, markers="s", color="blue", label="Train Time")
sns.pointplot(data=df_2, x="pool_size", y="OOD Training", ax=ax2, markers="s", color="red", label="Adapt Time")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='Wall Time (min)')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:16
#      13 ax2.yaxis.set_label_position("right")
#      14 ax2.yaxis.tick_right()
# ---> 16 sns.pointplot(data=df_2, x="pool_size", y="In-Domain Training", ax=ax2, markers="s", color="blue", label="Train Time")
#      17 sns.pointplot(data=df_2, x="pool_size", y="OOD Training", ax=ax2, markers="s", color="red", label="Adapt Time")
#      19 ax2.legend()
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:2479, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, color, palette, hue_norm, markers, linestyles, dodge, log_scale, native_scale, orient, capsize, formatter, legend, err_kws, ci, errwidth, join, scale, ax, **kwargs)
#    2467 def pointplot(
#    2468     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2469     estimator="mean", errorbar=("ci", 95), n_boot=1000, seed=None, units=None,
#    (...)
#    2474     ax=None, **kwargs,
#    2475 ):
#    2477     errorbar = utils._deprecate_ci(errorbar, ci)
# -> 2479     p = _CategoricalAggPlotter(
#    2480         data=data,
#    2481         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2482         order=order,
#    2483         orient=orient,
#    2484         # Handle special backwards compatibility where pointplot originally
#    2485         # did *not* default to multi-colored unless a palette was specified.
#    2486         color="C0" if (color is None and palette is None) else color,
#    2487         legend=legend,
#    2488     )
#    2490     if ax is None:
#    2491         ax = plt.gca()
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `In-Domain Training` for `y`. An entry with this name does not appear in `data`.

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="In-Domain Training")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="OOD Training")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='Wall Time (min)')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="In-Domain")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="OOD")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='Wall Time (min)')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="white")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrid")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrids")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/gb21553/Projects/Nodax/examples/lotka-voltera/runs/ContextPoolSizeExperiment/results_analysis.py:40
#      38 import seaborn as sns
#      39 import numpy as np
# ---> 40 sns.set_theme(style="whitegrids")
#      41 sns.set_context("poster")
#      42 f, (ax) = plt.subplots(figsize=(7, 6))
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:120, in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#      84 """
#      85 Set aspects of the visual theme for all matplotlib and seaborn plots.
#      86
#    (...)
#     117
#     118 """
#     119 set_context(context, font_scale)
# --> 120 set_style(style, rc={"font.family": font})
#     121 set_palette(palette, color_codes=color_codes)
#     122 if rc is not None:
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:331, in set_style(style, rc)
#     303 def set_style(style=None, rc=None):
#     304     """
#     305     Set the parameters that control the general style of the plots.
#     306
#    (...)
#     329
#     330     """
# --> 331     style_object = axes_style(style, rc)
#     332     mpl.rcParams.update(style_object)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/seaborn/rcmod.py:185, in axes_style(style, rc)
#     183 styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     184 if style not in styles:
# --> 185     raise ValueError(f"style must be one of {', '.join(styles)}")
#     187 # Define colors here
#     188 dark_gray = ".15"
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="ticks")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

import pandas as pd

## Assign each folder a new name
ncf_sample_sizes = [1, 2, 3, 4, 5, 6, 7, 8, 9]


losses1 = [1, 5.224747e-05, 6.783795e-05, 7.0833776e-05]
losses2 = [2, 5.0034e-05, 6.39028e-05, 7.0070906e-05]
losses3 = [3, 4.799081e-05, 6.0690767e-05, 5.5933084e-05]
losses4 = [4, 4.5672597e-05, 5.9366954e-05, 5.397191e-05]
losses5 = [5, 4.9214803e-05, 6.705255e-05, 6.757589e-05]
losses6 = [6, 4.933634e-05, 6.0242553e-05, 5.828382e-05]
losses7 = [7, 4.6182045e-05, 5.7319776e-05, 6.194386e-05]
losses8 = [8, 4.7197453e-05, 9.5398645e-05, 5.47559e-05]
losses9 = [9, 4.4913377e-05, 5.6144734e-05, 5.2251427e-05]

times1 = [1, 51*60+21, 34, 26, 26, 31, 59]
times2 = [2, (60+13)*60+31, 34, 26, 27, 29, 68]
times3 = [3, (60+24)*60+24, 33, 26, 27, 29, 71]
times4 = [4, (60+35)*60+28, 34, 26, 28, 27, 72]
times5 = [5, (60+45)*60+15, 34, 26, 29, 28, 73]
times6 = [6, (60+57)*60+13, 33, 26, 29, 28, 72]
times7 = [7, (120+10)*60+17, 33, 25, 29, 27, 72]
times8 = [8, (120+22)*60+50, 34, 26, 29, 27, 72]
times9 = [9, (120+32)*60+43, 34, 26, 29, 28, 72]


## Create a dataframe with each line a data point
df_1 = pd.DataFrame(data = [losses1, losses2, losses3, losses4, losses5, losses6, losses7, losses8, losses9], columns = ['pool_size', 'ind', 'ood_seq', 'ood_batch'])

df_2 = pd.DataFrame(data = [times1, times2, times3, times4, times5, times6, times7, times8, times9], columns = ['pool_size', 'ind_train (s)', 'ood_seq_1 (s)', 'ood_seq_2 (s)', 'ood_seq_3 (s)', 'ood_seq_4 (s)', 'ood_batch (s)'])
df_2['train_time'] = df_2['ind_train (s)']/60.
df_2['adapt_time'] = df_2['ood_batch (s)']/60.


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="darkgrid")
sns.set_context("poster")
f, (ax) = plt.subplots(figsize=(7, 6))

## Plot the in-domain loss vs the pool size
sns.pointplot(data=df_1, x="pool_size", y="ind", ax=ax, markers="o", color="purple", label="In-Domain")
sns.pointplot(data=df_1, x="pool_size", y="ood_batch", ax=ax, markers="o", color="green", label="OOD")

ax.legend()
ax.set(xlabel='Context Pool Size', ylabel='MSE')


## Save figure as a pdf
plt.savefig('context_pool_size_losses.pdf', format='pdf', dpi=600, bbox_inches='tight')

# %%
#%%

## Plot the train and adapt times
# ax2 = ax.twinx()
f, ax2 = plt.subplots(figsize=(7, 6))
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

sns.pointplot(data=df_2, x="pool_size", y="train_time", ax=ax2, markers="s", color="blue", label="In-Domain")
sns.pointplot(data=df_2, x="pool_size", y="adapt_time", ax=ax2, markers="s", color="red", label="OOD")

ax2.legend()
ax2.set(xlabel='Context Pool Size', ylabel='Wall Time (min)')


plt.savefig('context_pool_size_training_times.pdf', format='pdf', dpi=1200, bbox_inches='tight')
